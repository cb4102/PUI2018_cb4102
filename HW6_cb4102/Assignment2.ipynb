# %%
SQL_SOURCE = 'https://fb55.carto.com/api/v2/sql?q='

import urllib2
import urllib
import StringIO
import ast
import pandas as pd

def queryCartoDB(query, format='CSV', source=SQL_SOURCE):
    '''queries carto datasets from a given carto account
    Arguments: 
    query - string: a valid sql query string
    format - outlut format  OPTIONAL (default CSV)
    source - a valid sql api endpoint OPTIONAL (default carto fb55 account)
    Returns:
    the return of the sql query AS A STRING
    NOTES:
    designed for the carto API, tested only with CSV return format'''
    
    data = urllib.urlencode({'format': format, 'q': query})
    try:
        response = urllib2.urlopen(source, data)
    except urllib2.HTTPError, e:
        raise ValueError('\n'.join(ast.literal_eval(e.readline())['error']))
    except Exception:
        raise
    return response.read()

# %%
test = '''
SELECT *
FROM citibike_short
'''

# %%
citi = pd.read_csv(StringIO.StringIO(queryCartoDB(test)), sep=',')

# %%
citi.head()
# Out:
#    the_geom  start_station_longitude  the_geom_webmercator  tripduration  \
# 0       NaN               -73.994811                   NaN           801
# 1       NaN               -73.985649                   NaN           245
# 2       NaN               -73.990093                   NaN           379
# 3       NaN               -73.973715                   NaN          2474
# 4       NaN               -74.004704                   NaN           818
#
#        starttime       stoptime  start_station_id  \
# 0  2/1/2015 0:00  2/1/2015 0:14               521
# 1  2/1/2015 1:03  2/1/2015 1:07               438
# 2  2/1/2015 0:00  2/1/2015 0:07               497
# 3  2/1/2015 0:01  2/1/2015 0:42               281
# 4  2/1/2015 0:01  2/1/2015 0:15              2004
#
#                   start_station_name  start_station_latitude  cartodb_id  \
# 0                    8 Ave & W 31 St               40.750450           1
# 1                St Marks Pl & 1 Ave               40.727791          89
# ...

# %%
task1a = '''
SELECT *

FROM citibike_short

WHERE tripduration <= 180

ORDER BY start_station_id, tripduration
'''

# %%
pd.read_csv(StringIO.StringIO(queryCartoDB(task1a)), sep=',')
# Out:
#     the_geom  start_station_longitude  the_geom_webmercator  tripduration  \
# 0        NaN               -74.010434                   NaN            89
# 1        NaN               -73.987140                   NaN           151
# 2        NaN               -73.986724                   NaN           177
# 3        NaN               -74.001670                   NaN           171
# 4        NaN               -73.990741                   NaN           169
# 5        NaN               -73.981854                   NaN           159
# 6        NaN               -73.984738                   NaN           155
# 7        NaN               -73.997044                   NaN           164
# 8        NaN               -73.987030                   NaN           144
# 9        NaN               -73.985649                   NaN           167
# 10       NaN               -73.981948                   NaN           148
# 11       NaN               -73.988557                   NaN           114
# ...

# %%
task1b = '''
SELECT TOP 10 *, BOTTOM 10 *

FROM citibike_short

'''

# %%
task1c = '''
SELECT DISTINCT start_station_id
FROM citibike_short

'''

# %%
task1d = '''
SELECT COUNT(*) as cnt

FROM citibike_short

'''

task1e = '''
SELECT AVG(tripduration) as avg, 
MIN(tripduration) as min, 
MAX(tripduration) as max

FROM citibike_short


'''

# %%
pd.read_csv(StringIO.StringIO(queryCartoDB(task1b)), sep=',')

# %%
pd.read_csv(StringIO.StringIO(queryCartoDB(task1c)), sep=',')
# Out:
#      start_station_id  Unnamed: 1
# 0                 482         NaN
# 1                 483         NaN
# 2                 498         NaN
# 3                 285         NaN
# 4                 195         NaN
# 5                 539         NaN
# 6                 499         NaN
# 7                 453         NaN
# 8                 447         NaN
# 9                 461         NaN
# 10                281         NaN
# 11                401         NaN
# 12                335         NaN
# 13                382         NaN
# 14                267         NaN
# 15               2022         NaN
# 16                327         NaN
# 17                328         NaN
# 18                212         NaN
# 19                383         NaN
# 20                417         NaN
# 21                434         NaN
# 22                449         NaN
# 23                300         NaN
# 24                293         NaN
# 25                223         NaN
# ...

# %%
pd.read_csv(StringIO.StringIO(queryCartoDB(task1d)), sep=',')
# Out:
#    cnt  Unnamed: 1
# 0  199         NaN

# %%
pd.read_csv(StringIO.StringIO(queryCartoDB(task1e)), sep=',')
# Out:
#           avg  min    max
# 0  775.527638   89  35251

# %%
task2a = '''

SELECT *,  CONVERT(DATETIME, starttime, 101) as date

FROM citibike_short


'''

# %%
pd.read_csv(StringIO.StringIO(queryCartoDB(task2a)), sep=',')
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-45-0c68d4f17bfc> in <module>()
# ----> 1 pd.read_csv(StringIO.StringIO(queryCartoDB(task2a)), sep=',')
#
# <ipython-input-1-5cd119cb74c2> in queryCartoDB(query, format, source)
#      22         response = urllib2.urlopen(source, data)
#      23     except urllib2.HTTPError, e:
# ---> 24         raise ValueError('\n'.join(ast.literal_eval(e.readline())['error']))
#      25     except Exception:
#      26         raise
#
# ValueError: column "datetime" does not exist

# %%
task3a = '''

SELECT start_station_id, start_station_longitude, start_station_latitude

FROM citibike_short 

GROUP BY start_station_id,  start_station_longitude, start_station_latitude

'''

# %%
pd.read_csv(StringIO.StringIO(queryCartoDB(task3a)), sep=',')
# Out:
#      start_station_id  start_station_longitude  start_station_latitude
# 0                 345               -73.997044               40.736494
# 1                 472               -73.981948               40.745712
# 2                 119               -73.978034               40.696089
# 3                 300               -73.990214               40.728145
# 4                 461               -73.982050               40.735877
# 5                 498               -73.988084               40.748549
# 6                 312               -73.989111               40.722055
# 7                 238               -74.008592               40.736197
# 8                 528               -73.977061               40.742909
# 9                 503               -73.987520               40.738274
# 10                271               -73.978058               40.685282
# 11                279               -74.001670               40.707873
# ...

# %%
task3b = '''

SELECT start_station_id, count(end_station_id) as count

FROM citibike_short

WHERE start_station_latitude < (40.7577+0.004504505) 

AND start_station_latitude > (40.7577-0.004504505) 

AND start_station_longitude < ()

AND start_station_longitude > ()

GROUP BY start_station_id

'''

# %%
pd.read_csv(StringIO.StringIO(queryCartoDB(task3b)), sep=',')
# Out:
#      start_station_id  count
# 0                 482      1
# 1                 483      1
# 2                 498      3
# 3                 285      6
# 4                 195      1
# 5                 539      2
# 6                 499      2
# 7                 453      3
# 8                 447      2
# 9                 461      2
# 10                281      1
# 11                401      5
# 12                335      3
# 13                382      1
# 14                267      1
# 15               2022      1
# 16                327      1
# 17                328      2
# 18                212      1
# 19                383      2
# 20                417      1
# 21                434      2
# 22                449      2
# 23                300      3
# 24                293      4
# 25                223      2
# 26                128      5
# 27                501      1
# 28                433      1
# 29                394      1
# ..                ...    ...
# ...

# %%
task4 = '''

SELECT 

FROM 

GROUP BY

'''
